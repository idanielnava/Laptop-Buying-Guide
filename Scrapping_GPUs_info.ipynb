# %% [markdown]
# <a href="https://colab.research.google.com/github/idanielnava/Laptop-Buying-Guide/blob/main/Scrapping_GPUs_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#url= 'https://www.tomshardware.com/reviews/gpu-hierarchy,4388.html'
#url= 'https://www.videocardbenchmark.net/gpu_list.php'
url= 'https://benchmarks.ul.com/compare/best-gpus' #really good, doesnt match tho

# %%
list_= pd.read_html(url, header= 0)
list_[0]
# Out:
#      Rank                                       Device MSRP Price  \
# 0       1            AMD Radeon 6900 XT  DirectX 12.00       $999
# 1       2       NVIDIA GeForce RTX 3090  DirectX 12.00      $1499
# 2       3    NVIDIA GeForce RTX 3080 Ti  DirectX 12.00      $1199
# 3       4         AMD Radeon RX 6800 XT  DirectX 12.00       $649
# 4       5  NVIDIA GeForce RTX 3080 12GB  DirectX 12.00        NaN
# ..    ...                                          ...        ...
# 194   195       Intel Iris Graphics 520  DirectX 12.00        NaN
# 195   196         NVIDIA GeForce GT 730  DirectX 12.00        $59
# 196   197        Intel HD Graphics 5500  DirectX 12.00        NaN
# 197   198        Intel HD Graphics 4600  DirectX 12.00        NaN
# 198   199         NVIDIA GeForce GT 710  DirectX 12.00        $34
#
#      3DMark Graphics Score  Value for Money  Popularity
# 0                    20353             20.0         3.9
# 1                    19949             13.0         5.6
# ...

# %%
type(list_)
# Out:
# list

# %%
list_[0]
# Out:
#      Rank                                       Device MSRP Price  \
# 0       1            AMD Radeon 6900 XT  DirectX 12.00       $999
# 1       2       NVIDIA GeForce RTX 3090  DirectX 12.00      $1499
# 2       3    NVIDIA GeForce RTX 3080 Ti  DirectX 12.00      $1199
# 3       4         AMD Radeon RX 6800 XT  DirectX 12.00       $649
# 4       5  NVIDIA GeForce RTX 3080 12GB  DirectX 12.00        NaN
# ..    ...                                          ...        ...
# 194   195       Intel Iris Graphics 520  DirectX 12.00        NaN
# 195   196         NVIDIA GeForce GT 730  DirectX 12.00        $59
# 196   197        Intel HD Graphics 5500  DirectX 12.00        NaN
# 197   198        Intel HD Graphics 4600  DirectX 12.00        NaN
# 198   199         NVIDIA GeForce GT 710  DirectX 12.00        $34
#
#      3DMark Graphics Score  Value for Money  Popularity
# 0                    20353             20.0         3.9
# 1                    19949             13.0         5.6
# ...

# %%
gpu_ranking= pd.DataFrame(list_[0], columns= ['Rank', 'Device', 'MSRP Price', 	'3DMark Graphics Score', 'Value for Money', 'Popularity'])
gpu_ranking= gpu_ranking[['Rank', 'Device', '3DMark Graphics Score', 'Value for Money']]
gpu_ranking.head()
# Out:
#    Rank                                       Device  3DMark Graphics Score  \
# 0     1            AMD Radeon 6900 XT  DirectX 12.00                  20353
# 1     2       NVIDIA GeForce RTX 3090  DirectX 12.00                  19949
# 2     3    NVIDIA GeForce RTX 3080 Ti  DirectX 12.00                  19615
# 3     4         AMD Radeon RX 6800 XT  DirectX 12.00                  19086
# 4     5  NVIDIA GeForce RTX 3080 12GB  DirectX 12.00                  18770
#
#    Value for Money
# 0             20.0
# 1             13.0
# 2             16.0
# 3             29.0
# 4              NaN

# %%
#imports needed for Google Sheets
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.colab import auth

#verification from account for reading files you have acces to
auth.authenticate_user()
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
gpu_ranking.to_csv('/content/drive/MyDrive/BUSINESS/CVs/Portfolio Laptops/gpus_database.csv', encoding='utf-8', index= False)
